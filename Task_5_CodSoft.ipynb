# %% [markdown]
# <a href="https://colab.research.google.com/github/ADC1811/CODSOFT/blob/main/Task_5_CodSoft.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Importing all the important Dependencies**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import os
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %% [markdown]
# **Data Loading and Preprocessing**

# %%
df=pd.read_csv('/content/creditcard.csv')
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.dropna(inplace=True)
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
df['Class'].value_counts()
# Out:
# 0.0    39597
# 1.0      104
# Name: Class, dtype: int64

# %%
legit=df[df.Class==0]
fraud=df[df.Class==1]
print(legit.shape)
print(fraud.shape)
# Out:
# (39597, 31)
# (104, 31)

# %%
legit.Amount.describe()
# Out:
# count    39597.000000
# mean        87.420700
# std        234.514383
# min          0.000000
# 25%          7.420000
# 50%         23.500000
# 75%         79.000000
# max       7879.420000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     104.000000
# mean       97.070769
# std       255.012160
# min         0.000000
# 25%         1.000000
# 50%         3.775000
# 75%        99.990000
# max      1809.680000
# Name: Amount, dtype: float64

# %%
df.groupby('Class').mean()
# Out:
#                Time        V1        V2         V3        V4        V5  \
# Class
# 0.0    25514.725686 -0.194310  0.036967   0.744162  0.174545 -0.217414
# 1.0    20683.201923 -7.697309  5.766703 -10.853666  5.865850 -5.424996
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.107151 -0.093182  0.031783  0.222434  ...  0.046047 -0.031386
# 1.0   -2.275717 -7.641867  3.827809 -2.924282  ...  0.663205  0.626795
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.111706 -0.039470  0.007851  0.135895  0.022779  0.005987  0.003920
# 1.0   -0.345972 -0.342944 -0.230514  0.299242  0.176522  0.811431  0.099914
#
#           Amount
# Class
# 0.0    87.420700
# 1.0    97.070769
#
# [2 rows x 30 columns]

# %% [markdown]
# **Implementing UnderSampling**

# %%
legit_sample=legit.sample(n=104)

# %%
new_df=pd.concat([legit_sample,fraud],axis=0)
new_df.head()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 28964  35255  1.093027  0.069188  0.785234  1.205533 -0.698503 -0.537038
# 14855  26134  1.195411  0.280718  0.268736  0.650516 -0.188973 -0.598329
# 5464    5473 -0.884206  1.271462  0.926405  1.059926  0.916171  1.090672
# 10905  18706  1.218006 -0.420345  0.899142 -0.695603 -1.054803 -0.298452
# 7168    9396  1.191161  0.144434  0.657416  1.058375 -0.468309 -0.644686
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 28964 -0.203626  0.076301  0.019771  ... -0.006642 -0.165081  0.031710
# 14855  0.024958 -0.070775  0.019250  ... -0.253769 -0.715836  0.150075
# 5464   0.356729  0.063349  1.051596  ... -0.152200  0.027926 -0.321025
# 10905 -0.867671  0.136529  3.091501  ... -0.146195 -0.043523 -0.064242
# 7168  -0.060374 -0.241687  1.694507  ... -0.364978 -0.656684 -0.000121
#
#             V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
new_df['Class'].value_counts()
# Out:
# 0.0    104
# 1.0    104
# Name: Class, dtype: int64

# %%
new_df.groupby('Class').mean()
# Out:
#                Time        V1        V2         V3        V4        V5  \
# Class
# 0.0    26203.009615 -0.053713  0.038233   0.820813  0.196253 -0.097924
# 1.0    20683.201923 -7.697309  5.766703 -10.853666  5.865850 -5.424996
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.214338 -0.055174  0.037052  0.199920  ...  0.077677 -0.009237
# 1.0   -2.275717 -7.641867  3.827809 -2.924282  ...  0.663205  0.626795
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.160765 -0.102761 -0.049254  0.136538 -0.057819  0.030986  0.003656
# 1.0   -0.345972 -0.342944 -0.230514  0.299242  0.176522  0.811431  0.099914
#
#           Amount
# Class
# 0.0    82.350096
# 1.0    97.070769
#
# [2 rows x 30 columns]

# %% [markdown]
# **Data Splitting**

# %%
X=new_df.drop(columns='Class',axis=1)
y=new_df['Class']
print(X)
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 28964  35255  1.093027  0.069188  0.785234  1.205533 -0.698503 -0.537038
# 14855  26134  1.195411  0.280718  0.268736  0.650516 -0.188973 -0.598329
# 5464    5473 -0.884206  1.271462  0.926405  1.059926  0.916171  1.090672
# 10905  18706  1.218006 -0.420345  0.899142 -0.695603 -1.054803 -0.298452
# 7168    9396  1.191161  0.144434  0.657416  1.058375 -0.468309 -0.644686
# ...      ...       ...       ...       ...       ...       ...       ...
# 30473  35942 -4.194074  4.382897 -5.118363  4.455230 -4.812621 -1.224645
# 30496  35953 -4.844372  5.649439 -6.730396  5.252842 -4.409566 -1.740767
# 31002  36170 -5.685013  5.776516 -7.064977  5.902715 -4.715564 -1.755633
# 33276  37167 -7.923891 -5.198360 -3.000024  4.420666  2.272194 -3.394483
# 39183  39729 -0.964567 -1.643541 -0.187727  1.158253 -2.458336  0.852222
#
#              V7        V8        V9  ...       V20       V21       V22  \
# ...

# %% [markdown]
# **Data Model Selection**

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,stratify=y,random_state=42)
print(X.shape,X_train.shape,X_test.shape)
# Out:
# (208, 30) (166, 30) (42, 30)

# %% [markdown]
# **Training the Model**

# %%
model=LogisticRegression()
model.fit(X_train,y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %% [markdown]
# **Model Evaluaion**

# %%
#For Training Data
train_predict=model.predict(X_train)
train_accuracy=accuracy_score(train_predict,y_train)
print('Accuracy Score of Training Data: ',train_accuracy*100)
# Out:
# Accuracy Score of Training Data:  96.3855421686747

# %%
#For Testing Data
test_predict=model.predict(X_test)
test_accuracy=accuracy_score(test_predict,y_test)
print('Accuracy Score of Testing Data: ',test_accuracy*100)
# Out:
# Accuracy Score of Testing Data:  95.23809523809523
